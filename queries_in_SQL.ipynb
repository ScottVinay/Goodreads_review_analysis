# %% [markdown]
# <br>
# <br>
#
# ***
# ***
# # &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; Replication of Pandas queries in SQL
# ***
# ***
#
# <br>
# <br>

# %% [markdown]
# ### Here, we take the queries that are done in Pandas in `sentiment_revs.ipynb` and replicate them in SQL (sqlite).

# %%
import pandas as pd
from sqlalchemy import create_engine
sql = create_engine('sqlite://', echo=False)
# Out:
# /Users/Scott/anaconda/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: compiletime version 3.6 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.5
#   return f(*args, **kwds)

# %%
# Load data for sentiment analysis
revs = pd.read_csv('br.csv',nrows=300000)
revs = revs.rename(index=str, columns={'reviewerName':'name', 'ratingsCount':'count', 'reviewerRatings':'revrat'})

# Send to an SQL database
revs.to_sql('revs_sql',con=sql)

# %%
def sqsq(query,out=None,con=sql):
    df = pd.read_sql_query(query,con)
    if type(out)==type(''):
        df.to_sql(out,con)
    return df

# %%
print('Number of rows =',sql.execute('''
    SELECT COUNT(*) 
    FROM revs_sql
''').scalar())
print('Number of unique reviewers =',sql.execute('''
    SELECT COUNT(DISTINCT name) 
    FROM revs_sql
''').scalar())
revs.head(10)
# Out:
# Number of rows = 300000
# Number of unique reviewers = 77587
#    bookID                                              title  \
# 0       9  Unauthorized Harry Potter Book Seven News: "Ha...
# 1       8  Harry Potter Boxed Set, Books 1-5 (Harry Potte...
# 2       3              Harry Potter and the Sorcerer's Stone
# 3       1  Harry Potter and the Half-Blood Prince (Harry ...
# 4       2  Harry Potter and the Order of the Phoenix (Har...
# 5       4  Harry Potter and the Chamber of Secrets (Harry...
# 6       7   The Harry Potter Collection (Harry Potter, #1-6)
# 7       5  Harry Potter and the Prisoner of Azkaban (Harr...
# 8    8053                   Charlie Oink (Easy Peasy People)
# 9       6  Harry Potter and the Goblet of Fire (Harry Pot...
#
#                    author  rating    count  reviewsCount  \
# 0  W. Frederick Zimmerman    3.73       22             1
# 1            J.K. Rowling    4.77    34107           156
# 2            J.K. Rowling    4.44  4911929         77741
# 3            J.K. Rowling    4.54  1810404         28053
# 4            J.K. Rowling    4.47  1862749         29308
# 5            J.K. Rowling    4.38  1936698         35055
# 6            J.K. Rowling    4.73    26702           909
# 7            J.K. Rowling    4.53  2000827         37005
# 8        Roger Hargreaves    4.33        3             0
# 9            J.K. Rowling    4.53  1897821         31817
#
#                     name  revrat  \
# 0              Charles G     3.0
# 1  ✿Katherine Elizabeth✿     5.0
# 2                   Lora     5.0
# 3      Cait (Paper Fury)     5.0
# 4  Diane ϟ [ Lestrange ]     5.0
# 5                    Zoë     5.0
# 6             Jen Holman     5.0
# 7                   Inge     5.0
# 8                 Ashton     5.0
# 9                    Zoë     5.0
#
#                                               review
# 0                                                NaN
# 1                                                NaN
# 2  I'm going to keep this brief since there isn't...
# 3  "Read Harry Potter!" they said. "It'll be fun!...
# 4                                                NaN
# 5                                                NaN
# 6  I do not own this spiffy box set of Harry Pott...
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN

# %% [markdown]
# First we want to filter out duplicate reviews, which exist as shown here, and we want to filter out rows that have no review or no rating.

# %%
sqsq("""
SELECT *
FROM revs_sql
WHERE title='Ivanhoe' and name LIKE '%Bill%'
""")
# Out:
#    index  bookID    title        author  rating  count  reviewsCount  \
# 0    166    6445  Ivanhoe  Walter Scott    3.75  72149          1837
# 1    167    6444  Ivanhoe  Walter Scott    3.75  72153          1837
# 2    825    6440  Ivanhoe  Walter Scott    3.75  72147          1837
# 3    826    6443  Ivanhoe  Walter Scott    3.75  72147          1837
# 4  39340   40500  Ivanhoe  Walter Scott    3.75  72169          1838
# 5  87614   93114  Ivanhoe  Walter Scott    3.75  72172          1838
#
#            name  revrat review
# 0  Bill  Kerwin     4.0   None
# 1  Bill  Kerwin     4.0   None
# 2  Bill  Kerwin     4.0   None
# 3  Bill  Kerwin     4.0   None
# 4  Bill  Kerwin     4.0   None
# 5  Bill  Kerwin     4.0   None

# %%
def cleanDF(dfIn):
    query = """
    SELECT MIN(bookID) AS bookID, title, author, rating, count, reviewsCount, name, revrat, review
    FROM revs_sql 
    WHERE (review IS NOT NULL) AND (revrat IS NOT NULL)
    GROUP BY title, name
    """
    return pd.read_sql_query(query,sql)
revs = cleanDF(revs)
revs.to_sql('revs_sql_clean',con=sql)

# %%
sqsq('SELECT * FROM revs_sql_clean LIMIT 3')
# Out:
#    index  bookID           title       author  rating   count  reviewsCount  \
# 0      0   19340    Black Beauty  Anna Sewell    3.94  197106          3468
# 1      1  239055    Grass Dancer  Susan Power    3.93    2036           120
# 2      2   27330       Hiroshima  John Hersey    3.94   44328          2152
#
#                     name  revrat  \
# 0                  James     3.0
# 1                  Zanna     5.0
# 2  Paquita Maria Sanchez     5.0
#
#                                               review
# 0       Review\n  \nBlack Beauty by Anna Sewell i...
# 1  What I said in the secrecy of my thoughts was:...
# 2  This book will:1) Make you cry. A lot. You wil...

# %%
int('s')

# %%
sqsq('''
    SELECT * 
    FROM revs_sql_clean AS t1
    INNER JOIN (
        SELECT name
        FROM revs_sql
        GROUP BY name
        ORDER BY COUNT(name) DESC
        LIMIT 10
        ) AS t2
    WHERE t1.name==t2.name AND NOT t1.name=="BookDB"
''','revs_sql_clean_top_revs')
# Out:
#       index   bookID                                              title  \
# 0        10    76214                                 The Valley of Fear
# 1        12   295475                            Anthony and Cleopatra
# 2        23   154421                                           The Law
# 3        26   240419                       دنباله ی جستجو در تصوف ايران
# 4        27   259682                                         لذات فلسفه
# 5        31   119971                                  "Cinema Paradiso"
# 6        74   166082  'Honour': Crimes, Paradigms, and Violence Agai...
# 7        95   181800       (جانِ شیفته (دورۀ چهارجلدی (L'âme enchantée)
# 8        97   185493                               (کلیدر (دوره ۱۰ جلدی
# 9       174    86755  1001 Curious Things: Ye Olde Curiosity Shop an...
# 10      216   275791  12 Short Stories and Their Making: An Antholog...
# 11      228    32095                    13 Ways of Looking at the Novel
# 12      251    92064                                               1602
# 13      355  9441293  2005 Complete US Zip-Area Code Directory: 3 Wa...
# 14      418   228356                 30 Days of Night: Immortal Remains
# 15      447   244631        365 Dalai Lama: Daily Advice from the Heart
# 16      501   203373                  501 Essential Backgammon Problems
# 17      516   286266         635 Tage im Eis: Die Shackleton-Expedition
# 18      523     2252  7 Habits of Highly Effective People: Powerful ...
# 19      536   150238                                     77 Dream Songs
# 20      566   162074        99 Ways to Tell a Story: Exercises in Style
# 21      600     3463                                 A Bend in the Road
# 22      643   868668                                 A Book of Nonsense
# 23      719   219279  A Candle for d'Artagnan (Atta Olivia Clemens, #3)
# 24      721   164155                           A Canticle For Leibowitz
# 25      722    77386                           A Canticle for Leibowitz
# 26      741    21597                    A Catskill Eagle (Spenser, #12)
# 27      744   224743  A Century of Noir: Thirty-two Classic Crime St...
# 28      827   319238                             A Clergyman's Daughter
# 29      831    31424   A Closer Look at Ariel: A Memory of Sylvia Plath
# ...     ...      ...                                                ...
# 4376  91835    79454                                    چند روایت معتبر
# 4377  91838   230181                          چهل نامه‌ی کوتاه به همسرم
# 4378  91847   151320                                         کبریت خیس
# 4379  91848   139515                                         کلاس پرنده
# 4380  91850   174769                                              کلیدر
# 4381  91853   237573                                              کنیزو
# 4382  91856   254853                                             گالیور
# 4383  91859   120967                            گزارش به نسل بی سن فردا
# 4384  91861   163339                                        گزینه اشعار
# 4385  91865   167557                                            گفته ها
# 4386  91867   254446                                      گوژپشت نتردام
# 4387  91871    79449                                    یک عاشقانه آرام
# 4388  91872   207957                                  یک عاشقانه ی آرام
# 4389  91873   194563                                  یک عاشقانه‌ی آرام
# 4390  91881   314574                                    アドルフに告ぐ, Vol. 1
# 4391  91896    13606                                   ヒカルの碁 11、１人目の合格者
# 4392  91897    13611                                   ヒカルの碁 12、新初段シリーズ
# 4393  91898    13598                                     ヒカルの碁 13、プロ第一戦
# 4394  91899    13600                          ヒカルの碁 14、sai vs toya koyo
# 4395  91900    13596                                     ヒカルの碁 15、さよなら
# 4396  91901    13602                                      ヒカルの碁 16、中国棋院
# 4397  91902    13601                                   ヒカルの碁 17、なつかしい笑顔
# 4398  91903    13593                                       ヒカルの碁 18、番外編
# 4399  91904    13597                                      ヒカルの碁 19、最高初段
# 4400  91905    13613                                  ヒカルの碁 20、社 vs ヒカル
# 4401  91906    13610                                    ヒカルの碁 21、北斗杯会場へ
# 4402  91907    13609                                     ヒカルの碁 22、打倒高永夏
# 4403  91909    13599                              ヒカルの碁 8、プロ試験予選４日目そしてー
# 4404  91910    13608                                       ヒカルの碁 9、本戦開始
# 4405  91979   158825                                                造雨人
#
#                     author  rating   count  reviewsCount              name  \
# 0       Arthur Conan Doyle    3.98   21893          1153           Stephen
# 1      William Shakespeare    3.67   24459           865      Bill  Kerwin
# 2         Frédéric Bastiat    4.39    7920           602           Stephen
# 3      عبدالحسین زرّین‌کوب    3.50      36             3  Ahmad Sharabiani
# 4              Will Durant    3.91     808            60  Ahmad Sharabiani
# 5       Giuseppe Tornatore    4.20     157            10  Ahmad Sharabiani
# 6            Lynn Welchman    4.18      17             1             Chris
# 7           Romain Rolland    4.02    1109            58  Ahmad Sharabiani
# 8         محمود دولت‌آبادی    4.26    2322           184  Ahmad Sharabiani
# 9           Kate C. Duncan    3.75       4             1           Stephen
# 10         Paul Mandelbaum    3.81      79            12             Chris
# 11             Jane Smiley    3.78     931           159             David
# 12             Neil Gaiman    3.93   47079          1393           Stephen
# 13       Office TimeSavers    5.00       1             1             Chris
# 14     Jeffrey J. Mariotte    3.87     236            14              John
# 15          Dalai Lama XIV    4.07     337            29             Sarah
# 16           Bill Robertie    4.19      43             6             Manny
# 17          Alfred Lansing    4.36   55119          3563           Stephen
# 18        Stephen R. Covey    4.05  344970          6303           Stephen
# 19           John Berryman    4.14     695            45      Bill  Kerwin
# 20             Matt Madden    3.84     602            81             David
# 21         Nicholas Sparks    4.02  123996          3415  Ahmad Sharabiani
# 22             Edward Lear    3.65    1415           127             Manny
# 23    Chelsea Quinn Yarbro    3.94     248             9             Chris
# 24    Walter M. Miller Jr.    3.97   73075          3657             Manny
# 25    Walter M. Miller Jr.    3.97   73046          3656             Manny
# 26        Robert B. Parker    4.04    5234           210      Bill  Kerwin
# 27         Mickey Spillane    4.05      56            11           Michael
# 28           George Orwell    3.45    4003           313  Ahmad Sharabiani
# 29    Nancy Hunter Steiner    3.69      68             8              John
# ...                    ...     ...     ...           ...               ...
# 4376       Mostafa Mastoor    3.16    1608            73  Ahmad Sharabiani
# 4377        Nader Ebrahimi    3.61    1399           102  Ahmad Sharabiani
# 4378            عباس صفاری    3.61     442            42  Ahmad Sharabiani
# 4379         Erich Kästner    4.14    2283            97             Manny
# 4380   Mahmoud Dowlatabadi    4.26    2322           184  Ahmad Sharabiani
# 4381      مُنیرو روانی‌پور    3.24     160             9  Ahmad Sharabiani
# 4382        Jonathan Swift    3.55  190651          4046           Stephen
# 4383         Reza Baraheni    3.23      26             4  Ahmad Sharabiani
# 4384            نیما یوشیج    3.79     234             9  Ahmad Sharabiani
# 4385        ابراهیم گلستان    3.52      88             6  Ahmad Sharabiani
# 4386           Victor Hugo    3.97  135591          3333      Bill  Kerwin
# 4387        Nader Ebrahimi    3.57    3150           306  Ahmad Sharabiani
# 4388        Nader Ebrahimi    3.57    3152           308  Ahmad Sharabiani
# 4389        Nader Ebrahimi    3.57    3152           308  Ahmad Sharabiani
# 4390          Osamu Tezuka    4.14     852            46             Sarah
# 4391            Yumi Hotta    4.27     777            17             David
# 4392            Yumi Hotta    4.23     727            13             David
# 4393            Yumi Hotta    4.25     681            16             David
# 4394            Yumi Hotta    4.23     571            10             David
# 4395            Yumi Hotta    4.25     526            17             David
# 4396            Yumi Hotta    4.16     506            14             David
# 4397            Yumi Hotta    4.24     529            16             David
# 4398            Yumi Hotta    4.11     484            15             David
# 4399            Yumi Hotta    4.25     557            10             David
# 4400            Yumi Hotta    4.19     489            12             David
# 4401            Yumi Hotta    4.19     550            12             David
# 4402            Yumi Hotta    4.21     510             9             David
# 4403            Yumi Hotta    4.22     893            14             David
# 4404            Yumi Hotta    4.27     924            16             David
# 4405          John Grisham    3.91  144062          1557           Stephen
#
#       revrat                                             review  \
# 0        4.0   Let’s face it, Sherlock Holmes is a prig. A v...
# 1        5.0  This play is so good, it is not merely a maste...
# 2        5.0  6.0 stars. The newest member of my list of "Al...
# 3        4.0  ادامه، شاید هم «جلد دوم» همان «جستجو در تصوف» ...
# 4        5.0  The Pleasures of Philosophy, Will Durant عنوان...
# 5        4.0  Nuovo cinema Paradiso, Giuseppe Tornatore تاری...
# 6        4.0  I want to smack people right now. Not because ...
# 7        5.0  L'âme enchantée, Romain Rollandتاریخ نخستین خو...
# 8        5.0  Kelidar, Mahmoud Dowlatabadi عنوان: کلیدر؛ نوی...
# 9        4.0  This book is a stellar study of a particular n...
# 10       3.0  Honestly, I was rather disappointed by this on...
# 11       5.0  So many books .... so little time. Last year I...
# 12       4.0  Dear Mr. Gaiman and Nameless Marvel Suits: I’d...
# 13       5.0  Great for businesses and people alike, this zi...
# 14       3.0  IMMORTAL REMAINS may not be a first-rate vampi...
# 15       3.0  At best this book was sentimental, at worst it...
# 16       4.0  Attention backgammon players: this book really...
# 17       5.0  Behold...the gentleman whose exploits crushed ...
# 18       1.0      I would like to make clear that David Hass...
# 19       5.0  Have your ever met a person who does something...
# 20       3.0  This is Raymond Queneau's "Exercises in Style"...
# 21       4.0  A Bend in the Road, Nicholas Sparksعنوان: در پ...
# 22       4.0  I grew up reading A Book of Nonsense, which le...
# 23       5.0  This was the first Yarbro vampire book that I ...
# 24       4.0  I'm not a Christian, but I live in a Christian...
# 25       4.0  I'm not a Christian, but I live in a Christian...
# 26       3.0  For years I believed it was here, at #12 in th...
# 27       4.0  Mickey Spillane and Max Allan Collins team up ...
# 28       4.0  A Clergyman's Daughter, George Orwell عنوان: د...
# 29       3.0  The book is about 80 pages long. One section i...
# ...      ...                                                ...
# 4376     4.0  Chand Ravayate Mo'tabar, Mostafa Mastoor تاریخ...
# 4377     4.0  40 Name ye Kotah Be Hamsaram, Nader Ebrahimiتا...
# 4378     4.0  Kebrite-Khis, Abbas Safariعنوان: کبریت خیس - م...
# 4379     5.0  There were two episodes in this German childre...
# 4380     5.0  Kelidar, Mahmoud Dowlatabadi عنوان: کلیدر؛ نوی...
# 4381     4.0  Kanizu (1988), Moniru RavaniporMoniro Ravanipo...
# 4382     3.0  Let’s face it…. Jonathan Swift was a snarky, s...
# 4383     4.0  Gozaresh be Nasle Bisen-e Farda, Reza Baraheni...
# 4384     5.0  Nima Yooshij Selected Poems, Nima Yooshijتاریخ...
# 4385     4.0  Utterances = Words-Spoken, Ebrahim Golestan (T...
# 4386     5.0  I recently read Victor Hugo's Notre Dame de Pa...
# 4387     4.0  Yek Aasheghaneye Aaram, Nader Ebrahimi از کتاب...
# 4388     4.0  Yek Aasheghaneye Aaram, Nader Ebrahimi از کتاب...
# 4389     4.0  Yek Aasheghaneye Aaram, Nader Ebrahimi از کتاب...
# 4390     5.0  Who said Graphic Novels can't be entertaining ...
# 4391     5.0  Once again, the beauty of this series is its a...
# 4392     4.0  Now that Hikaru is a professional go player (a...
# 4393     4.0  Now that Hikaru is a professional go player, h...
# 4394     3.0  So, this volume didn't jump the shark, but I a...
# 4395     3.0  So, there was one thing I liked in this otherw...
# 4396     4.0  So I was kind of skeptical when most of this v...
# 4397     4.0  The only really important thing that happens i...
# 4398     3.0  Volume 17 ended with what should have been the...
# 4399     4.0  Although this was really only an average insta...
# 4400     4.0  So we're now in the final arc of the series, w...
# 4401     3.0  Meh, pretty much a "filler" volume as the play...
# 4402     4.0  This penultimate volume finally heats the susp...
# 4403     4.0  Hikaru now enters the preliminary tests to joi...
# 4404     5.0  I've been burning through this series lately, ...
# 4405     3.0  “I'm alone and outgunned, scared and inexperie...
#
#                   name
# 0              Stephen
# 1         Bill  Kerwin
# 2              Stephen
# 3     Ahmad Sharabiani
# 4     Ahmad Sharabiani
# 5     Ahmad Sharabiani
# 6                Chris
# 7     Ahmad Sharabiani
# 8     Ahmad Sharabiani
# 9              Stephen
# 10               Chris
# 11               David
# 12             Stephen
# 13               Chris
# 14                John
# 15               Sarah
# 16               Manny
# 17             Stephen
# 18             Stephen
# 19        Bill  Kerwin
# 20               David
# 21    Ahmad Sharabiani
# 22               Manny
# 23               Chris
# 24               Manny
# 25               Manny
# 26        Bill  Kerwin
# 27             Michael
# 28    Ahmad Sharabiani
# 29                John
# ...                ...
# 4376  Ahmad Sharabiani
# 4377  Ahmad Sharabiani
# 4378  Ahmad Sharabiani
# 4379             Manny
# 4380  Ahmad Sharabiani
# 4381  Ahmad Sharabiani
# 4382           Stephen
# 4383  Ahmad Sharabiani
# 4384  Ahmad Sharabiani
# 4385  Ahmad Sharabiani
# 4386      Bill  Kerwin
# 4387  Ahmad Sharabiani
# 4388  Ahmad Sharabiani
# 4389  Ahmad Sharabiani
# 4390             Sarah
# 4391             David
# 4392             David
# 4393             David
# 4394             David
# 4395             David
# 4396             David
# 4397             David
# 4398             David
# 4399             David
# 4400             David
# 4401             David
# 4402             David
# 4403             David
# 4404             David
# 4405           Stephen
#
# [4406 rows x 11 columns]

# %%
cols = 'bookID, title, author, rating, count, reviewsCount, name, revrat, review'

# %%
countQueries = ['''
SELECT name, COUNT(name) AS count{0}
FROM revs_sql_clean_top_revs
WHERE revrat=={0}
GROUP BY name
'''.format(i) for i in [1,3,4,5]]

sqsq('''
    SELECT 
        t0.name,
        rating AS croRatMean,
        AVG(revrat) AS revRatMean,
        count1,
        count3,
        count4,
        count5
    
    FROM revs_sql_clean_top_revs AS t0
    
    LEFT JOIN ({}) AS t1 ON t0.name=t1.name
    LEFT JOIN ({}) AS t3 ON t0.name=t3.name
    LEFT JOIN ({}) AS t4 ON t0.name=t4.name
    LEFT JOIN ({}) AS t5 ON t0.name=t5.name
    
    GROUP BY t0.name
'''.format(*countQueries))
# Out:
#                name  croRatMean  revRatMean  count1  count3  count4  count5
# 0  Ahmad Sharabiani        3.50    4.066667     NaN     104     674     167
# 1      Bill  Kerwin        3.67    4.408163     NaN      60     199     280
# 2             Chris        4.18    3.886297    20.0      91     120     112
# 3             David        3.78    3.827652    34.0     136     211     147
# 4              John        3.87    3.974441    15.0      77     107     114
# 5             Manny        4.19    4.004167    14.0     110     202     154
# 6           Michael        4.05    3.923267    23.0      98     147     136
# 7             Sarah        4.07    3.625407    34.0      88     110      75
# 8           Stephen        3.98    3.970750    24.0     143     181     199
